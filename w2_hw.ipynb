# %% [markdown]
# You are given a score N on a 10-point scale.
#
# Your task is to convert the numeric score into a letter grade based on the following rules:
#
# N ≥ 8.5 → A
#
# 7.0 ≤ N < 8.5 → B
#
# 5.5 ≤ N < 7.0 → C
#
# 4.0 ≤ N < 5.5 → D
#
# N < 4.0 → F
#
# Input
# The input consists of one real number N (0 ≤ N ≤ 10).
#
# Output
# Print the corresponding letter grade (A, B, C, D, or F).
#
# For example:
#
# |Input|Result|
# |---|---|
# |8.5|A|
#
# Answer:
# (penalty regime: 10, 20, ... %)
