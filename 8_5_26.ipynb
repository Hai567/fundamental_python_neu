# %%
class Product:
    def __init__(self, id, name, price, quant):
        self.__id = id
        self.__name = name
        self.__price = price
        self.__quant = quant
    
    def updateQuant(self, amount):
        self.__quant = self.__quant + amount
        return f"Updated quantity to {self.__quant}"
    
    def getTotalValue(self):
        return self.__price * self.__quant
    
    def __repr__(self):
        return f"Product id: {self.__id}, name: {self.__name}, price: {self.__price}, quantity: {self.__quant}"
    

class WareHouse: 
    def __init__(self):
        self.__products = {}
    
    def load_from_file(self, filename):
        with open(filename, "r") as f:
            for line in f:
                prd_id, prd_name, prd_price, prd_quant = line.split(":")
                self.__products[prd_id] = {}
    
    def add_product(self, product):
        pass
    
    def save_report(self, filename):
        pass
