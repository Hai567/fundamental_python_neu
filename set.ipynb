# %%
a = [{'key1': 'value1'}, {'key2': 'value2'}]

for key, value in a[0].items():
    print(key, value)
# Out:
# key1 value1

# %%
student = [
    {"Nu": 2006}: [111,222,333],
    {"Nam": 2006}: [444,227,3233]
]

for key, value in student[0].items():
    print(key, value)
# Out:
#   Cell In[6], line 2
#     {"Nu": 2006}: [111,222,333],
#                 ^
# SyntaxError: invalid syntax
